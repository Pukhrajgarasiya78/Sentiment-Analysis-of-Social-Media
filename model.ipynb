# %%
#New One
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
plt.style.use('ggplot')
import nltk

# %%
pip install nltk

# %%
#read in data
df = pd.read_csv(r"D:\ml\Sentiment.csv")

# %%
df.head()
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                     1.0   Neutral                0.6578  None of the above
# 1                     1.0  Positive                0.6333  None of the above
# 2                     1.0   Neutral                0.6629  None of the above
# 3                     1.0  Positive                1.0000  None of the above
# 4                     1.0  Positive                0.7045  None of the above
#
#    subject_matter_confidence candidate_gold  ... relevant_yn_gold  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13871 entries, 0 to 13870
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         13871 non-null  int64
#  1   candidate                  13775 non-null  object
#  2   candidate_confidence       13871 non-null  float64
#  3   relevant_yn                13871 non-null  object
#  4   relevant_yn_confidence     13871 non-null  float64
#  5   sentiment                  13871 non-null  object
#  6   sentiment_confidence       13871 non-null  float64
#  7   subject_matter             13545 non-null  object
#  8   subject_matter_confidence  13871 non-null  float64
#  9   candidate_gold             28 non-null     object
#  10  name                       13871 non-null  object
#  11  relevant_yn_gold           32 non-null     object
#  12  retweet_count              13871 non-null  int64
# ...

# %%
df=df.drop(['sentiment'],axis=1)

# %%
df.head()
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence  sentiment_confidence     subject_matter  \
# 0                     1.0                0.6578  None of the above
# 1                     1.0                0.6333  None of the above
# 2                     1.0                0.6629  None of the above
# 3                     1.0                1.0000  None of the above
# 4                     1.0                0.7045  None of the above
#
#    subject_matter_confidence candidate_gold             name relevant_yn_gold  \
# 0                     1.0000            NaN       I_Am_Kenzi              NaN
# ...

# %%
df['tweet'] = df['text'].str.replace(r'@[\w]*', '', regex=True)

# %%
df.head()
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence  sentiment_confidence     subject_matter  \
# 0                     1.0                0.6578  None of the above
# 1                     1.0                0.6333  None of the above
# 2                     1.0                0.6629  None of the above
# 3                     1.0                1.0000  None of the above
# 4                     1.0                0.7045  None of the above
#
#    subject_matter_confidence candidate_gold             name  ...  \
# 0                     1.0000            NaN       I_Am_Kenzi  ...
# ...

# %%
df['tweet'] = df['tweet'].str.replace("[^a-zA-Z#]", " ")
df.head()
# Out:
# C:\Users\Pukhraj Garasiya\AppData\Local\Temp\ipykernel_12384\1246801750.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['tweet'] = df['tweet'].str.replace("[^a-zA-Z#]", " ")
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence  sentiment_confidence     subject_matter  \
# 0                     1.0                0.6578  None of the above
# 1                     1.0                0.6333  None of the above
# 2                     1.0                0.6629  None of the above
# 3                     1.0                1.0000  None of the above
# ...

# %%
df['tweet'] = df['tweet'].apply(lambda x: " ".join([w for w in x.split() if len(w)>3]))
df.head(100)
# Out:
#      id               candidate  candidate_confidence relevant_yn  \
# 0     1  No candidate mentioned                1.0000         yes
# 1     2            Scott Walker                1.0000         yes
# 2     3  No candidate mentioned                1.0000         yes
# 3     4  No candidate mentioned                1.0000         yes
# 4     5            Donald Trump                1.0000         yes
# ..  ...                     ...                   ...         ...
# 95   96            Donald Trump                1.0000         yes
# 96   97                Jeb Bush                0.4413         yes
# 97   98  No candidate mentioned                1.0000         yes
# 98   99             Marco Rubio                0.4535         yes
# 99  100            Donald Trump                1.0000         yes
#
#     relevant_yn_confidence  sentiment_confidence     subject_matter  \
# 0                   1.0000                0.6578  None of the above
# ...

# %%
df['tweet'] = df['tweet'].str.replace("[^a-zA-Z#]", " ")
df.head()
# Out:
# C:\Users\Pukhraj Garasiya\AppData\Local\Temp\ipykernel_12384\1246801750.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['tweet'] = df['tweet'].str.replace("[^a-zA-Z#]", " ")
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence  sentiment_confidence     subject_matter  \
# 0                     1.0                0.6578  None of the above
# 1                     1.0                0.6333  None of the above
# 2                     1.0                0.6629  None of the above
# 3                     1.0                1.0000  None of the above
# ...

# %%
df['tweet'].values[0:2]
# Out:
# array(['everyone feel about Climate Change question last night Exactly #GOPDebate',
#        'Didn catch full #GOPdebate last night Here some Scott best lines seconds #Walker http ZSfF'],
#       dtype=object)

# %%
df['tweet'] = df['tweet'].replace(to_replace=r'^https?:\/\/.*[\r\n]*',value='',regex=True)

df.head()
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence  sentiment_confidence     subject_matter  \
# 0                     1.0                0.6578  None of the above
# 1                     1.0                0.6333  None of the above
# 2                     1.0                0.6629  None of the above
# 3                     1.0                1.0000  None of the above
# 4                     1.0                0.7045  None of the above
#
#    subject_matter_confidence candidate_gold             name  ...  \
# 0                     1.0000            NaN       I_Am_Kenzi  ...
# ...

# %%
df['tweet'].values[0:2]
# Out:
# array(['everyone feel about Climate Change question last night Exactly #GOPDebate',
#        'Didn catch full #GOPdebate last night Here some Scott best lines seconds #Walker http ZSfF'],
#       dtype=object)

# %%
print(df.shape)
df=df.head(500)
print(df.shape)
# Out:
# (13871, 21)
# (500, 21)

# %%
#basic NlTK
example = df['tweet'][50]
print(example)
# Out:
# best worst from #GOPDebate http

# %%
tokens=nltk.word_tokenize(example)
tokens[:10]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 tokens=nltk.word_tokenize(example)
#       2 tokens[:10]
#
# File D:\ana\lib\site-packages\nltk\tokenize\__init__.py:129, in word_tokenize(text, language, preserve_line)
#     114 def word_tokenize(text, language="english", preserve_line=False):
#     115     """
#     116     Return a tokenized copy of *text*,
#     117     using NLTK's recommended word tokenizer
#    (...)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132     ]
#
# File D:\ana\lib\site-packages\nltk\tokenize\__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
# ...

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File D:\ana\lib\socket.py:833, in create_connection(address, timeout, source_address)
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 nltk.download('averaged_perceptron_tagger')
#
# File D:\ana\lib\site-packages\nltk\downloader.py:777, in Downloader.download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
# ...

# %%
tagged=nltk.pos_tag(tokens)
tagged[:10]

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')

# %%
entities=nltk.chunk.ne_chunk(tagged)
entities.pprint()

# %%
 nltk.download('vader_lexicon')

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('I am not angry')

# %%
sia.polarity_scores('This is the worst thing ever')

# %%
sia.polarity_scores(example)

# %%
res={}
for i, row in tqdm(df.iterrows(),total=len(df)):
    text = row['text']
    myid = row['id']
    res[myid]=sia.polarity_scores(text)

# %%
vaders=pd.DataFrame(res).T
vaders=vaders.reset_index().rename(columns={'index':'id'})
vaders=vaders.merge(df, how ='left')

# %%
#now we have sentiment score and metadata
vaders.head(20)

# %%
vaders.dtypes

# %%
mean_negative=vaders["neg"].mean()
print(mean_negative*100)

# %%
mean_positive=vaders["pos"].mean()
print(mean_positive*100)

# %%
mean_neu=vaders["neu"].mean()
print(mean_neu*100)

# %%
sizes=[mean_positive,mean_negative,mean_neu]
label=['postive','negative','neutral']

fig = plt.figure(figsize =(10, 7))
plt.pie(sizes,labels = label)

# show plot
plt.show()

# %%
pickle.dump(vaders,open('twittersentiment.pkl','wb'))

# %%
model = pickle.load(open('twittersentiment.pkl','rb'))
